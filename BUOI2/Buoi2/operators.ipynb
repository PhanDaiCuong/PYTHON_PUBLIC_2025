# %% [markdown]
# # 🧮 Toán tử trong Python
#
# Python hỗ trợ nhiều loại toán tử để thực hiện các phép toán trên biến và giá trị.
#
# ---
#
# ## 1. Toán tử số học (Arithmetic Operators)
#
# | Toán tử | Ý nghĩa             | Ví dụ       |
# |---------|---------------------|-------------|
# | `+`     | Cộng                | `x + y`     |
# | `-`     | Trừ                 | `x - y`     |
# | `*`     | Nhân                | `x * y`     |
# | `/`     | Chia                | `x / y`     |
# | `//`    | Chia lấy phần nguyên| `x // y`    |
# | `%`     | Chia lấy dư         | `x % y`     |
# | `**`    | Lũy thừa            | `x ** y`    |
#
# ---
#
# ## 2. Toán tử gán (Assignment Operators)
#
# | Toán tử | Ý nghĩa                    | Ví dụ        |
# |---------|----------------------------|--------------|
# | `=`     | Gán giá trị                | `x = 5`      |
# | `+=`    | Cộng rồi gán               | `x += 3`     |
# | `-=`    | Trừ rồi gán                | `x -= 2`     |
# | `*=`    | Nhân rồi gán               | `x *= 4`     |
# | `/=`    | Chia rồi gán               | `x /= 2`     |
# | `//=`   | Chia nguyên rồi gán        | `x //= 2`    |
# | `%=`    | Chia dư rồi gán            | `x %= 3`     |
# | `**=`   | Lũy thừa rồi gán           | `x **= 2`    |
#
# ---
#
# ## 3. Toán tử so sánh (Comparison Operators)
#
# | Toán tử | Ý nghĩa                     | Ví dụ        |
# |---------|-----------------------------|--------------|
# | `==`    | So sánh bằng                | `x == y`     |
# | `!=`    | Khác nhau                   | `x != y`     |
# | `>`     | Lớn hơn                     | `x > y`      |
# | `<`     | Nhỏ hơn                     | `x < y`      |
# | `>=`    | Lớn hơn hoặc bằng           | `x >= y`     |
# | `<=`    | Nhỏ hơn hoặc bằng           | `x <= y`     |
#
# ---
#
# ## 4. Toán tử logic (Logical Operators)
#
# | Toán tử | Ý nghĩa                     | Ví dụ             |
# |---------|-----------------------------|--------------------|
# | `and`   | Và – đúng khi cả hai đúng   | `x > 5 and x < 10` |
# | `or`    | Hoặc – đúng nếu một trong hai đúng | `x < 5 or x > 10` |
# | `not`   | Phủ định – đảo ngược kết quả | `not(x > 5)`      |
#
# ---
#
# ## 5. Toán tử thành viên (Membership Operators)
#
# | Toán tử | Ý nghĩa                         | Ví dụ             |
# |---------|----------------------------------|--------------------|
# | `in`    | Kiểm tra phần tử có trong chuỗi, list... | `'a' in 'abc'`    |
# | `not in`| Kiểm tra phần tử không có trong  | `'z' not in 'abc'`|
#
# ---
#
# ## 6. Toán tử nhận dạng (Identity Operators)
#
# | Toán tử | Ý nghĩa                                | Ví dụ         |
# |---------|-----------------------------------------|---------------|
# | `is`    | Kiểm tra 2 biến có cùng đối tượng không | `x is y`      |
# | `is not`| Kiểm tra 2 biến không cùng đối tượng    | `x is not y`  |
#
# ---
#
# ## 7. Toán tử bit (Bitwise Operators)
#
# | Toán tử | Ý nghĩa               | Ví dụ    |
# |---------|------------------------|----------|
# | `&`     | AND                    | `x & y`  |
# | `|`     | OR                     | `x | y`  |
# | `^`     | XOR                    | `x ^ y`  |
# | `~`     | NOT                    | `~x`     |
# | `<<`    | Dịch trái              | `x << 2` |
# | `>>`    | Dịch phải              | `x >> 2` |
#
# ---

# %% [markdown]
# ## 📌 1. Toán tử số học
#
# ### Bài 1:
# Viết chương trình nhập vào hai số nguyên `a` và `b`, tính và in ra:
# - Tổng, hiệu, tích
# - Thương và phần dư
# - `a` mũ `b`
#
# ## 📌 2. Toán tử gán
# ### Bài 2:
# Cho biến x = 10. Lần lượt:
#
# Cộng thêm 5
#
# Nhân đôi giá trị hiện tại
#
# Trừ đi 4
#
# Chia đôi giá trị hiện tại
#
# In ra kết quả cuối cùng.
#
# ## 📌 3. Toán tử so sánh
# ### Bài 3:
# Viết chương trình nhập tuổi một người, in ra:
#
# "Trẻ con" nếu dưới 12
#
# "Thiếu niên" nếu từ 12 đến dưới 18
#
# "Người lớn" nếu từ 18 trở lên
# ## 📌 4. Toán tử logic
# ### Bài 4:
# Viết chương trình kiểm tra xem một số x có thuộc khoảng từ 10 đến 100 hay không (bao gồm cả 10 và 100).
# ## 📌 5. Toán tử thành viên
# ### Bài 5:
# Viết chương trình kiểm tra xem ký tự ch có nằm trong chuỗi "hello world" hay không.
#
# ## 📌 6. Toán tử nhận dạng
# ### Bài 6:
# Tạo hai list a = [1, 2, 3] và b = [1, 2, 3]. Kiểm tra:
#
# a == b
#
# a is b
#
# Sau đó gán c = a và kiểm tra lại:
#
# a is c
#
# ## 📌 7. Toán tử bit
# ### Bài 7:
# Cho x = 12 và y = 5. In ra:
#
# x & y
#
# x | y
#
# x ^ y
#
# x << 2
#
# y >> 1
